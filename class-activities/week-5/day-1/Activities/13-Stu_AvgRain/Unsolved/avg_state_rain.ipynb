# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
csv_path = "../Resources/avg_rain_state.csv"
df = pd.read_csv(csv_path)
df.head(10)
# Out:
#          State  Inches  Milli­metres  Rank
# 0      Alabama    58.3          1480     4
# 1       Alaska    22.5           572    39
# 2      Arizona    13.6           345    47
# 3     Arkansas    50.6          1284     8
# 4   California    22.2           563    40
# 5     Colorado    15.9           405    44
# 6  Connecticut    50.3          1279     9
# 7     Delaware    45.7          1160    16
# 8      Florida    54.5          1385     5
# 9      Georgia    50.7          1287     7

# %%
# Set x axis and tick locations
x_axis = df["State"].tolist()
in_rain = df["Inches"].tolist()
plt.figure(figsize=(20,3))
plt.bar(x_axis, in_rain, color='r', alpha=.5, align="center")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# <BarContainer object of 50 artists>

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.xticks(rotation="vertical")
plt.xlim(-1, len(x_axis)+1)
# Out:
# (-1, 51)

# %%
# Set x and y limits

# %%
# Set a Title and labels

# %%
# Save our graph and show the grap
