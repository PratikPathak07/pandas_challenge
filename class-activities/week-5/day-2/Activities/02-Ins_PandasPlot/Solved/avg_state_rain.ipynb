# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(12,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="1200">
# ([<matplotlib.axis.XTick at 0x1d370bb2198>,
#   <matplotlib.axis.XTick at 0x1d3709459e8>,
#   <matplotlib.axis.XTick at 0x1d3709455f8>,
#   <matplotlib.axis.XTick at 0x1d370c61d30>,
#   <matplotlib.axis.XTick at 0x1d370c72240>,
#   <matplotlib.axis.XTick at 0x1d370c72710>,
#   <matplotlib.axis.XTick at 0x1d370c72c18>,
#   <matplotlib.axis.XTick at 0x1d370c791d0>,
#   <matplotlib.axis.XTick at 0x1d370c79748>,
#   <matplotlib.axis.XTick at 0x1d370c722e8>,
#   <matplotlib.axis.XTick at 0x1d370c79b70>,
#   <matplotlib.axis.XTick at 0x1d370c79e80>,
#   <matplotlib.axis.XTick at 0x1d370c80588>,
#   <matplotlib.axis.XTick at 0x1d370c80b00>,
#   <matplotlib.axis.XTick at 0x1d370c85128>,
#   <matplotlib.axis.XTick at 0x1d370c85630>,
#   <matplotlib.axis.XTick at 0x1d370c85ba8>,
#   <matplotlib.axis.XTick at 0x1d370c8e198>,
#   <matplotlib.axis.XTick at 0x1d370c855f8>,
#   <matplotlib.axis.XTick at 0x1d370c80630>,
#   <matplotlib.axis.XTick at 0x1d370c8e2b0>,
#   <matplotlib.axis.XTick at 0x1d370c8ecc0>,
#   <matplotlib.axis.XTick at 0x1d370c93278>,
#   <matplotlib.axis.XTick at 0x1d370c937f0>,
#   <matplotlib.axis.XTick at 0x1d370c93d68>,
#   <matplotlib.axis.XTick at 0x1d370c9a320>,
#   <matplotlib.axis.XTick at 0x1d370c9a898>,
#   <matplotlib.axis.XTick at 0x1d370c9ae10>,
#   <matplotlib.axis.XTick at 0x1d370c9a978>,
#   <matplotlib.axis.XTick at 0x1d370c93320>,
#   <matplotlib.axis.XTick at 0x1d370ca22e8>,
#   <matplotlib.axis.XTick at 0x1d370ca2860>,
#   <matplotlib.axis.XTick at 0x1d370ca2dd8>,
#   <matplotlib.axis.XTick at 0x1d370ca9390>,
#   <matplotlib.axis.XTick at 0x1d370ca9908>,
#   <matplotlib.axis.XTick at 0x1d370ca9e80>,
#   <matplotlib.axis.XTick at 0x1d370cb1438>,
#   <matplotlib.axis.XTick at 0x1d370ca9438>,
#   <matplotlib.axis.XTick at 0x1d370ca2668>,
#   <matplotlib.axis.XTick at 0x1d370cb1780>,
#   <matplotlib.axis.XTick at 0x1d370cb1eb8>,
#   <matplotlib.axis.XTick at 0x1d370cb8470>,
#   <matplotlib.axis.XTick at 0x1d370cb89e8>,
#   <matplotlib.axis.XTick at 0x1d370cb8f60>,
#   <matplotlib.axis.XTick at 0x1d370cbe518>,
#   <matplotlib.axis.XTick at 0x1d370cbea90>,
#   <matplotlib.axis.XTick at 0x1d370cc60b8>,
#   <matplotlib.axis.XTick at 0x1d370cbea58>,
#   <matplotlib.axis.XTick at 0x1d370cb1f98>,
#   <matplotlib.axis.XTick at 0x1d370cc64e0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
